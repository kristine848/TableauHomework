# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Name of the CSV file
file1 = 'Oct2019.csv'
file2= 'Nov2019.csv'
file3= 'Dec2019.csv'
file4= 'Jan2020.csv'
file5= 'Feb2020.csv'
file6= 'March2020.csv'

# %%
# The correct encoding must be used to read the CSV in pandas
df1 = pd.read_csv(file1, encoding="ISO-8859-1")
df2 = pd.read_csv(file2, encoding="ISO-8859-1")
df3 = pd.read_csv(file3, encoding="ISO-8859-1")
df4 = pd.read_csv(file4, encoding="ISO-8859-1")
df5 = pd.read_csv(file5, encoding="ISO-8859-1")
df6 = pd.read_csv(file6, encoding="ISO-8859-1")

# %%
# Preview of the DataFrame
# Note that FIELD8 is likely a meaningless column
df.head()
frames = [df1, df2, df3, df4, df4, df5, df6]
CombindedBikeData = pd.concat(frames)
CombindedBikeData
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               892  2019-10-01 00:20:05.0140  2019-10-01 00:34:57.3800
# 1               374  2019-10-01 00:43:48.8790  2019-10-01 00:50:03.8190
# 2               170  2019-10-01 01:35:51.8630  2019-10-01 01:38:42.5470
# 3               946  2019-10-01 02:55:53.4000  2019-10-01 03:11:40.2710
# 4               517  2019-10-01 03:10:16.1290  2019-10-01 03:18:53.6350
# ...             ...                       ...                       ...
# 17714           296  2020-03-31 22:50:39.0410  2020-03-31 22:55:35.5980
# 17715           147  2020-03-31 23:09:15.9690  2020-03-31 23:11:43.5310
# 17716           364  2020-03-31 23:17:02.0240  2020-03-31 23:23:06.8200
# 17717          1217  2020-03-31 23:36:10.6430  2020-03-31 23:56:27.8120
# 17718           846  2020-03-31 23:37:21.1840  2020-03-31 23:51:28.1220
#
#        start station id start station name  start station latitude  \
# ...

# %%
# CombinedBike=NewPositionCodes.set_index(['ChargeCD'])
CombindedBikeData.to_csv(r'Oct2019March2020BikeData.csv', index=False, header=True)
